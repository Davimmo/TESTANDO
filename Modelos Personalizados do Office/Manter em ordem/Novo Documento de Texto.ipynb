# %%
def troca_valores(listaA,listaB,valorinicial):
    novalista=list(listaA.keys())

    valorespassados=list(listaB.values())

    for i in novalista[valorinicial:]:
        
        listaA[i]=(valorespassados[int(novalista.index(i))])


## Variaveis para o começo
posições=list()
quinas=list()
meios=list()
centros=list()
nucleo=list()

##Listas dos lados que vão receber as posições do cubo
LadoU=[]
LadoL=[]
LadoF=[]
LadoR=[]
LadoB=[]
LadoD=[]

##Definição do cubo
class cubo:

    def start():
        
        for altura in range(1,4):
            for largura in range(1,4):
                for profundidade in range(1,4):
                    posições.append([profundidade,largura,altura])

        for peças in posições:
            if 2 not in peças:
                quinas.append(peças)
            
            elif peças.count(2)==2:
                centros.append(peças)
            
            elif peças==[2,2,2]:
                nucleo.append(peças)
            
            else:
                meios.append(peças)



    def gerar_quinas():print(f'Essas são as coordenadas das quinas:{quinas}')
    def gerar_meios():print(f'Essas são as coordenadas dos meio:{meios}')
    def gerar_centros():print(f'Essas são as coordenadas dos centros:{centros}')
    def gerar_nucleo():print(f'Essa é a coordenada do núcleo:{nucleo}')


##Geração do cubo
cubo.start()

##Procura por posições que preencham os requisitos de cada lado do cubo
def lado(posind,posicub,ladocu):
    

    for i in posições:
        if i[posind]==posicub:
            ladocu.append(i)

##Jogar essas posições nos lados respectivos:
lado(0,3,LadoU)
lado(1,1,LadoL)
lado(2,1,LadoF)
lado(1,3,LadoR)
lado(2,3,LadoB)
lado(0,1,LadoD)



##Criar um dicionario com as informações de cada peça
peças=dict()
dicpeças=[]

for i in posições:
    peças['num']=posições.index(i)+1
    peças['posição']=i


    if i in quinas:
        peças['Tipo de peça']='quina'
    if i in meios:
        peças['Tipo de peça']='meio'
    if i in centros:
        peças['Tipo de peça']='centro'
    if i in nucleo:
        peças['Tipo de peça']='nucleo'


    if i in LadoR: 
        peças ['azul']='PR'
    if i in LadoD: 
        peças['branco']='PD'
    if i in LadoU: 
        peças['amarelo']='PU'
    if i in LadoL: 
        peças['verde']='PL'
    if i in LadoB: 
        peças['vermelho']='PB'
    if i in LadoF: 
        peças['laranja']='PF'


    dicpeças.append(peças)
    peças=dict()



##Procura elementos especificos para as peças e retorna uma lista com cada elemento.

def procurar_no_dicio(a,b):
    ##Procura dentre os valores
    if a=='v':
        elementos_achados=[]
        indices=[]
        for i in dicpeças:
            temp=i.values()
            if b in temp:
                elementos_achados.append(i)
        
        for elemento in elementos_achados:
            indices.append(dicpeças.index(elemento))


        return indices

    ##Procura dentre as chaves
    elif a=='k':
        elementos_achados=[]
        indices=[]
        for i in dicpeças:
            temp=i.keys()
            if b in temp:
                elementos_achados.append(i)

        for elemento in elementos_achados:
            indices.append(dicpeças.index(elemento))


        return indices
        

todos_os_lados=[LadoU,LadoL,LadoF,LadoR,LadoB,LadoD]
todas_as_cores=['amarelo','verde','laranja','azul','vermelho','branco']



ciclo_de_U=[dicpeças[20],dicpeças[23],dicpeças[26],dicpeças[17],dicpeças[8],dicpeças[5],dicpeças[2],dicpeças[11]]
ciclo_de_L=[dicpeças[20],dicpeças[19],dicpeças[18],dicpeças[11],dicpeças[9],dicpeças[2],dicpeças[1],dicpeças[0]]
ciclo_de_F=[dicpeças[2],dicpeças[5],dicpeças[8],dicpeças[7],dicpeças[6],dicpeças[3],dicpeças[0],dicpeças[1]]
ciclo_de_R=[dicpeças[24],dicpeças[25],dicpeças[26],dicpeças[17],dicpeças[8],dicpeças[7],dicpeças[6],dicpeças[15]]
ciclo_de_B=[dicpeças[26],dicpeças[23],dicpeças[20],dicpeças[11],dicpeças[2],dicpeças[5],dicpeças[8],dicpeças[17]]
ciclo_de_D=[dicpeças[0],dicpeças[2],dicpeças[5],dicpeças[7],dicpeças[8],dicpeças[5],dicpeças[2],dicpeças[1]]

listadeciclos=[ciclo_de_U,ciclo_de_L,ciclo_de_F,ciclo_de_R,ciclo_de_B,ciclo_de_D]





def F():
    global ciclo_de_F
    ciclonovo=ciclo_de_F[2:]+ciclo_de_F[:2]



    ##Troca as posições do novo ciclo
    temp=0
    for algo_novo in ciclo_de_F:

        print(f'Ciclo de F {algo_novo}')

        Valor_do_Ciclo_Novo=ciclonovo[temp]['posição']
        algo_novo['posição']=Valor_do_Ciclo_Novo
        

        
        print(f'Novo {ciclonovo[temp]}')
        temp=temp+1
        print('----------------------------------------------------------')



    for coisas in ciclo_de_F:
        dicionario=coisas.items()
        for x,y in dicionario:
            
            if y=='PU':
                coisas[x]='PR'
            if y=='PR':
                coisas[x]='PD'
            if y=='PD':
                coisas[x]='PL'
            if y=='PL':
                coisas[x]='PU'

    print('Só aqui verdadeiramente me interessa nessa porra')

    
    



#falta corrigir as posições
F()
F()
F()
F()
# Out:
# Ciclo de F {'num': 3, 'posição': [3, 1, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# Novo {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 6, 'posição': [3, 2, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# Novo {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# Novo {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# Novo {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# Novo {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# Novo {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# Novo {'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# Novo {'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Só aqui verdadeiramente me interessa nessa porra
# Ciclo de F {'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PR', 'verde': 'PU', 'laranja': 'PF'}
# Novo {'num': 9, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PD', 'amarelo': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PR', 'laranja': 'PF'}
# Novo {'num': 8, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'azul': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 9, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PD', 'amarelo': 'PR', 'laranja': 'PF'}
# Novo {'num': 7, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PD', 'branco': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 8, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'azul': 'PD', 'laranja': 'PF'}
# Novo {'num': 4, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'branco': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 7, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PD', 'branco': 'PL', 'laranja': 'PF'}
# Novo {'num': 1, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PL', 'verde': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 4, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'branco': 'PL', 'laranja': 'PF'}
# Novo {'num': 2, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'verde': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 1, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PL', 'verde': 'PU', 'laranja': 'PF'}
# Novo {'num': 3, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PR', 'verde': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 2, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'verde': 'PU', 'laranja': 'PF'}
# Novo {'num': 6, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'amarelo': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Só aqui verdadeiramente me interessa nessa porra
# Ciclo de F {'num': 3, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PD', 'verde': 'PR', 'laranja': 'PF'}
# Novo {'num': 9, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PL', 'amarelo': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 6, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'amarelo': 'PD', 'laranja': 'PF'}
# Novo {'num': 8, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'azul': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 9, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PL', 'amarelo': 'PD', 'laranja': 'PF'}
# Novo {'num': 7, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PL', 'branco': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 8, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'azul': 'PL', 'laranja': 'PF'}
# Novo {'num': 4, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'branco': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 7, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PL', 'branco': 'PU', 'laranja': 'PF'}
# Novo {'num': 1, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PU', 'verde': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 4, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'branco': 'PU', 'laranja': 'PF'}
# Novo {'num': 2, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'verde': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 1, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PU', 'verde': 'PR', 'laranja': 'PF'}
# Novo {'num': 3, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'amarelo': 'PD', 'verde': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 2, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'verde': 'PR', 'laranja': 'PF'}
# Novo {'num': 6, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'amarelo': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Só aqui verdadeiramente me interessa nessa porra
# Ciclo de F {'num': 3, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'amarelo': 'PL', 'verde': 'PD', 'laranja': 'PF'}
# Novo {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PU', 'amarelo': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 6, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'amarelo': 'PL', 'laranja': 'PF'}
# Novo {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PU', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 9, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PU', 'amarelo': 'PL', 'laranja': 'PF'}
# Novo {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PU', 'branco': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 8, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'azul': 'PU', 'laranja': 'PF'}
# Novo {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PR', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 7, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PU', 'branco': 'PR', 'laranja': 'PF'}
# Novo {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PR', 'verde': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 4, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'branco': 'PR', 'laranja': 'PF'}
# Novo {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 1, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'branco': 'PR', 'verde': 'PD', 'laranja': 'PF'}
# Novo {'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PL', 'verde': 'PD', 'laranja': 'PF'}
# ----------------------------------------------------------
# Ciclo de F {'num': 2, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'verde': 'PD', 'laranja': 'PF'}
# Novo {'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PL', 'laranja': 'PF'}
# ----------------------------------------------------------
# Só aqui verdadeiramente me interessa nessa porra

# %%
def mostrar_tudo(iteravel):
    for tanto_faz in iteravel:
        print(tanto_faz)
    
    print('-----------------------------------------------------------------------------------')


def iterador(lista1,lista2):
    for tudo in lista1:
        



mostrar_tudo(ciclo_de_F)



ciclonovo=ciclo_de_F[2:]+ciclo_de_F[:2]

mostrar_tudo(ciclonovo)
# Out:
# {'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 9, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 8, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# {'num': 7, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 4, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 1, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 2, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# -----------------------------------------------------------------------------------
# {'num': 9, 'posição': [1, 3, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'amarelo': 'PU', 'laranja': 'PF'}
# {'num': 8, 'posição': [1, 2, 1], 'Tipo de peça': 'meio', 'azul': 'PR', 'laranja': 'PF'}
# {'num': 7, 'posição': [1, 1, 1], 'Tipo de peça': 'quina', 'azul': 'PR', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 4, 'posição': [2, 1, 1], 'Tipo de peça': 'meio', 'branco': 'PD', 'laranja': 'PF'}
# {'num': 1, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'branco': 'PD', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 2, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 3, 'posição': [3, 3, 1], 'Tipo de peça': 'quina', 'amarelo': 'PU', 'verde': 'PL', 'laranja': 'PF'}
# {'num': 6, 'posição': [2, 3, 1], 'Tipo de peça': 'meio', 'amarelo': 'PU', 'laranja': 'PF'}
# -----------------------------------------------------------------------------------

# %%
test_list = [1, 4, 6, 7, 2] 
print ("Original list : " + str(test_list)) 
test_list = test_list[3:] + test_list[:3] 
print ("List after left rotate by 3 : " + str(test_list)) 
test_list = test_list[-3:] + test_list[:-3] 
print ("List after right rotate by 3(back to original) : "
                                         + str(test_list))

# %%
# dicionario={'fruta':'pera','veiculo':'moto','moeda':'dolar'}
# dicionario.items()

# outrodic={'cor':'azul','nome':'roberto','carreira':'professor'}

# lista_de_itens=.items()

# for k,v in lista_de_itens:
#     print(k)
#     print(v)

testando=['cafe','coca','batata','pepino','churrasco']

testando[2]='pepino'

print(testando)
# Out:
# ['cafe', 'coca', 'pepino', 'pepino', 'churrasco']

# %%
davi=[1,2,3,4,5,6,7,8]
davi=davi[-2:]+davi[:-2]
print(davi)
# Out:
# [7, 8, 1, 2, 3, 4, 5, 6]
