# %%
import time
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome()
from selenium.webdriver.common.alert import Alert
alert=Alert(driver)



time.sleep(1)
driver.get("https://www.educacao.petrolina.pe.gov.br/ator/educadores")
driver.set_window_size(976, 1040)
driver.find_element(By.CSS_SELECTOR, "html").click()
driver.find_element(By.CSS_SELECTOR, ".LayoutLoginCampos").click()
driver.find_element(By.ID, "login").click()
driver.find_element(By.ID, "login").send_keys("Davi.BC")
driver.find_element(By.ID, "senha").send_keys("@Vk5644202510")
driver.find_element(By.ID, "senha").send_keys(Keys.ENTER)
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, ".menuAcessoRestrito").click()
time.sleep(1)
driver.find_element(By.LINK_TEXT, "Gestão Escolar").click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, ".icon-eol1331").click()
time.sleep(1)
driver.find_element(By.XPATH, "//div[3]/div/div/div/div").click()
time.sleep(1)
driver.find_element(By.XPATH, "//ul/li").click()
time.sleep(1)
driver.find_element(By.XPATH, "//ul/li[4]").click()
time.sleep(1)
driver.switch_to.frame(0)
time.sleep(1)

##Aqui começa o loop for para colocar o nome dos alunos

##Aqui vai o nome do aluno

Alunos=['KYARA SOPHIA PRACA PEREIRA DA SILVA',
'LARA MELINDA GOMES NASCIMENTO',
'LARISSA PORFIRIO SANTOS',
'LORENA DE SOUZA FERREIRA',
'LORENZO DE SOUZA FERREIRA',
'LUANA GABRIELLY DE SOUZA SILVA',
'LUANNA CECILIA BARBOSA BATISTA',
'LUIZ MIGUEL RODRIGUES DOS SANTOS',
'LUKAS FABRICIO NASCIMENTO GOMES',
'MARIA ALESSANDRA FIRMINO SILVA',
'MARIA BEATRIZ DA SILVA SA',
'MARIA CRISTAL HONORIO XAVIER',
'MARIA EDUARDA DO NASCIMENTO SILVA',
'MARIA ELIZIA MARQUES DA SILVA',
'MARIA HELOISA DA SILVA',
'MARIA YASMIN TOMAS DOS SANTOS',
'MARIA YSABELLE LOURENCO SINDOR',
'MAYCON GABRIEL DA CONCEICAO MACIEL',
'MAYCON GUILHERME DA SILVA SA',
'NOAN VITOR BATISTA SILVA',
'PEDRO EMANUEL COELHO GALDINO',
'PIETRO HENRIQUE ANDRADE DOS SANTOS',
'RAVI MAICON BARBOSA DE SOUZA',
'THALISON DE SOUZA BARBOSA',
'VALENTINA RAMALHO DA SILVA',
'YAGO DE SOUZA DO E'
]

Inep=[
'205575894361',
'205575896739',
'205575896577',
'205575891265',
'205575892237',
'206650379105',
'205575894604',
'206650479240',
'205575894019',
'205575892075',
'205575892741',
'205575894442',
'205575891850',
'205575892903',
'205575893470',
'205575893802',
'205575893390',
'205575894523',
'205575894795',
'205575895929',
'205575895090',
'205575891184',
'205575896496',
'205575894108',
'191919105106',
'205575896143'
]


var1=int(0)
time.sleep(1)


for Aluno in Alunos:
    driver.find_element(By.NAME, "txtAluno").send_keys(Alunos[var1])
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="lnk_pesquisar"]/img').click()
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[3]/div[4]/div/table/tbody/tr[2]/td[3]/label').click()
    time.sleep(2)
    driver.find_element(By.XPATH,'//*[@id="lnk_alterar"]/img').click()
    time.sleep(2)
    driver.find_element(By.XPATH,'//*[@id="tabCadastroAluno_tablist_cpDocumentos"]').click()
    time.sleep(2)
    
    ##Aqui vai o inepe 
    driver.find_element(By.XPATH,'//*[@id="cpDocumentos"]/table/tbody/tr[17]/td[2]/input').send_keys(Inep[var1])
    time.sleep(2)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr/td/input[1]').click()
    time.sleep(1)


    ##Aceita um póssivel alerta
    try: 
        alert.accept()
        time.sleep(2)
        driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr[3]/td[2]/input').clear()
    
    except:
        time.sleep(2)
        driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr[3]/td[2]/input').clear()
    
    
    var1+=1
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In [2], line 29
#      27 driver.find_element(By.XPATH, "//div[3]/div/div/div/div").click()
#      28 time.sleep(1)
# ---> 29 driver.find_element(By.XPATH, "//ul/li").click()
#      30 time.sleep(1)
#      31 driver.find_element(By.XPATH, "//ul/li[4]").click()
#
# File c:\Users\Usuário\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Usuário\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\Usuário\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=108.0.5359.96)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x002FF243]
# 	(No symbol) [0x00287FD1]
# 	(No symbol) [0x0017D04D]
# 	(No symbol) [0x00162D7A]
# 	(No symbol) [0x001CBE7B]
# 	(No symbol) [0x001DC196]
# 	(No symbol) [0x001C8386]
# 	(No symbol) [0x001A163C]
# 	(No symbol) [0x001A269D]
# 	GetHandleVerifier [0x00599A22+2655074]
# 	GetHandleVerifier [0x0058CA24+2601828]
# 	GetHandleVerifier [0x003A8C0A+619850]
# 	GetHandleVerifier [0x003A7830+614768]
# 	(No symbol) [0x002905FC]
# 	(No symbol) [0x00295968]
# 	(No symbol) [0x00295A55]
# 	(No symbol) [0x002A051B]
# 	BaseThreadInitThunk [0x7626FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C57A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C57A6E+238]
# 	(No symbol) [0x00000000]

# %%
Alunos=['LAZÁRO BERNARDO DO NASCIMENTO DELMAN	']
Inep=['111111111111']
var1=int(0)
time.sleep(3)


for Aluno in Alunos:
    driver.find_element(By.NAME, "txtAluno").send_keys(Alunos[var1])
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="lnk_pesquisar"]/img').click()
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[3]/div[4]/div/table/tbody/tr[2]/td[3]/label').click()
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="lnk_alterar"]/img').click()
    time.sleep(2)
    driver.find_element(By.XPATH,'//*[@id="tabCadastroAluno_tablist_cpDocumentos"]').click()
    time.sleep(2)
    
    ##Aqui vai o inepe 
    driver.find_element(By.XPATH,'//*[@id="cpDocumentos"]/table/tbody/tr[17]/td[2]/input').send_keys(Inep[var1])
    time.sleep(1)
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr/td/input[1]').click()
    time.sleep(1)
    ##Limpa o input
    driver.find_element(By.XPATH,'//*[@id="divCorpoGestaoEscolar"]/form/table/tbody/tr/td/div[2]/div[4]/div/table/tbody/tr[3]/td[2]/input').clear()
    
    var1+=1

# %%
driver.close()
